# %% [markdown]
# ### 문항 1 정중앙 문자
#
#
# 문자열을 전달 받아 해당 문자열의 정중앙 문자를 반환하는 get_middle_char 함수를 작성하시오.
#
#
# 단, 문자열의 길이가 짝수일 경우에는 정중앙 문자 2개를 반환한다.
#
# ```py
# get_middle_char('study') # => u
# get_middle_char('python') # => th
# ```

# %%
def get_middle_char(char):
    cnt = len(char)
    mid_idx = cnt // 2
    if cnt % 2 == 0:
        temp2 = char[mid_idx -1 : mid_idx +1]
        result = print(temp2)
    else: 
        temp2 = char[mid_idx]
        result = print(temp2)
        
    return result

# %%
get_middle_char('study')
# Out:
# u

# %%
get_middle_char('python')
# Out:
# th

# %% [markdown]
# ### 문항2 가변 인자 리스트
#
# 가변 인자 리스트를 사용하여, 개수가 정해지지 않은 여러 정수들을 전달 받아 해당 정수들의 평균 값을 반환하는 my_avg 함수를 작성하시오.
#
# ```py
# my_avg(77, 83, 95, 80, 70) #=> 81.0
# ```

# %%
def my_avg(*args):
    my_list = [*args]
    total = sum(my_list)
    cnt = len(my_list)
    result = total / cnt
    return result

# %%
my_avg(77, 83, 95, 80, 70)
# Out:
# 81.0
