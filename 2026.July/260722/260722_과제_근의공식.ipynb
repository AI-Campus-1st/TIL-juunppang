# %%
# 근의 공식 python
print('근의 공식 값 도출')
a = int(input('a의 값을 입력하세요:'))
b = int(input('b의 값을 입력하세요:'))
c = int(input('c의 값을 입력하세요:'))
print('입력한 방정식 : ax**2 + bx +c')
x1 = (-b + (b**2 - 4*a*c)**0.5)/(2*a)
x2 = (-b - (b**2 - 4*a*c)**0.5)/(2*a)
print('x1 =', complex(x1), 'x2=', complex(x2))
# Out:
# 근의 공식 값 도출
# 입력한 방정식 : ax**2 + bx +c
# x1 = (-2+0j) x2= (-3+0j)
